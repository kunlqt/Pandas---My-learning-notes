# %%
#https://github.com/IST256/learn-python/blob/master/content/lessons/12/Now-You-Code/NYC4-Exam-Scores.ipynb
import pandas as pd
URL='https://raw.githubusercontent.com/mafudge/datasets/master/exam-scores/exam-scores.csv'

# %%
df = pd.read_csv(URL)
df.head(5)aaaa
# Out:
#   Class Section Exam Version  Completion Time Made Own Study Guide  \
# 0           M01            A               20                    N
# 1           M01            A               20                    ?
# 2           M01            A               30                    Y
# 3           M01            A               50                    N
# 4           M01            A               55                    Y
#
#   Did Exam Prep Assignment Studied In Groups  Student Score Percentage  \
# 0                        N                 Y             24     80.00%
# 1                        ?                 ?             27     90.00%
# 2                        Y                 Y             30    100.00%
# 3                        Y                 Y             18     60.00%
# 4                        Y                 N             24     80.00%
#
#   Letter Grade
# 0            B
# 1           A-
# 2            A
# 3           C-
# 4            B

# %%
Class_Section = 'M01'
Exam_version = 'A'

# %%
#With valid inputs it should filter the DataFrame to only those rows matching the input (for example section M01, version A)

df_filter = df[(df['Class Section'] == Class_Section) & (df['Exam Version'] == Exam_version) ]
df_filter
# Out:
#   Class Section Exam Version  Completion Time Made Own Study Guide  \
# 0           M01            A               20                    N
# 1           M01            A               20                    ?
# 2           M01            A               30                    Y
# 3           M01            A               50                    N
# 4           M01            A               55                    Y
# 5           M01            A               60                    N
# 6           M01            A               60                    Y
#
#   Did Exam Prep Assignment Studied In Groups  Student Score Percentage  \
# 0                        N                 Y             24     80.00%
# 1                        ?                 ?             27     90.00%
# 2                        Y                 Y             30    100.00%
# 3                        Y                 Y             18     60.00%
# 4                        Y                 N             24     80.00%
# ...

# %%
#And display only the Student Score and Letter Grade for each student matching the inputs.
df_few_fields = df_filter[['Student Score','Letter Grade']]
df_few_fields
# Out:
#    Student Score Letter Grade
# 0             24            B
# 1             27           A-
# 2             30            A
# 3             18           C-
# 4             24            B
# 5             25            B
# 6             30            A

# %%
from Ipython.display import display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-ba6607c5b753> in <module>()
# ----> 1 from Ipython.display import display
#
# ModuleNotFoundError: No module named 'Ipython'

# %%
from ipywidgets import widgets
test = widgets.Text
